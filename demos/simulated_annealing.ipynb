# %%
import sys
sys.path.append('../')
from simulated_annealing import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /scratch-local/slurm-job-tmp-4048815/ipykernel_55/1602109619.py in <cell line: 3>()
#       1 import sys
#       2 sys.path.append('../')
# ----> 3 from simulated_annealing import *
#
# ModuleNotFoundError: No module named 'simulated_annealing'

# %%
G = nx.random_internet_as_graph(12)
pos = nx.spring_layout(G)
nx.draw_networkx(G, pos, with_labels=True)

# %%
init_state = initial_state_bipartition(G)

init_partitions = bipartition_to_set(G, init_state)

community_output_graph(G, init_partitions, "Initial State", pos)

# %%
best_state, best_fitness = simulated_annealing(G, init_state, max_iter=2000, T=100, alpha=0.99)
new_partitions = bipartition_to_set(G, best_state)
community_output_graph(G, new_partitions, "Final State", pos)

# %%
len(simulated_annealing.states)
# Out:
# 143
